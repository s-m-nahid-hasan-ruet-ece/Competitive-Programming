# %% [markdown]
# ### Multi-Channel Signal

# %%
import numpy as np
import matplotlib.pyplot as plt


t = np.linspace(-0.02, 0.05, 1000)
plt.plot(t,(15*np.sin(2*np.pi*50*t)+20*np.sin(2*np.pi*40*t)+25*np.sin(2*np.pi*30*t)));
plt.xlabel('t');
plt.ylabel('x(t)');
plt.title(r'Plot of Multi Channel Signal');
plt.xlim([-0.02, 0.05]);
plt.show()

# %% [markdown]
# ### Multidimendional Signal

# %%
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt

x = np.outer(np.linspace(-2, 2, 10), np.ones(10))
y = x.copy().T
z = np.cos(x ** 2 + y ** 3)

fig = plt.figure()

ax = plt.axes(projection ='3d')

ax.plot_surface(x, y, z, cmap ='viridis', edgecolor ='green')
ax.set_title('3 Dimensional Signal')
plt.show()

# %% [markdown]
# ### Continuous Time Signal

# %%
import numpy as np
import matplotlib.pyplot as plt


t = np.linspace(-0.02, 0.05, 1000)
plt.plot(t, 325 * np.sin(2*np.pi*50*t));
plt.xlabel('t');
plt.ylabel('x(t)');
plt.title(r'Plot of CT signal x(t)=325 sin(2 pi 50 t)');
plt.xlim([-0.02, 0.05]);
plt.show()

# %% [markdown]
# ### Discrete Time Signal

# %%
n = np.arange(50)
dt = 0.07/50
x = np.sin(2 * np.pi * 50 * n * dt)
plt.xlabel('n')
plt.ylabel('x[n]')
plt.title(r'Plot of DT signal x[n] = 325*sin(2*pi*50*n*Delta t)')
plt.stem(n, x)
# Out:
# <StemContainer object of 3 artists>

# %% [markdown]
# ### Continuous Valued Signal

# %%
import numpy as np
import matplotlib.pyplot as plt


t = np.linspace(-0.02, 0.05, 1000)
plt.plot(t, 325 * np.sin(2*np.pi*50*t));
plt.xlabel('t');
plt.ylabel('x(t)');
plt.title(r'Plot of CT signal x(t)=325 sin(2 pi 50 t)');
plt.xlim([-0.02, 0.05]);
plt.show()

# %% [markdown]
# ### Discrete Valued Signal

# %%
import random as rnd
import numpy as np
import matplotlib.pyplot as plt

data = np.arange(10)
x = np.arange(3)
xs = np.repeat(range(len(data)), 2)
ys = np.repeat(data, 2)
xs = xs[1:]
ys = ys[:-1]
xs = np.append(xs,xs[-1] + 1)
ys = np.append(ys, ys[-1])
plt.plot(xs, ys)
plt.ylim(-0.5, 7)
plt.show()

# %% [markdown]
# ### Deterministic Signal

# %%
import random as rnd
import numpy as np
import matplotlib.pyplot as plt

data = [1,0,1,0,1,0,1,0]
x = np.arange(3)
xs = np.repeat(range(len(data)), 20)
ys = np.repeat(data, 20)

xs = np.repeat(xs,100)
ys = np.repeat(ys,100)
xs = xs[1:]
ys = ys[:-1]
xs = np.append(xs,xs[-1] + 1)
ys = np.append(ys, ys[-1])
plt.plot(xs, ys)
plt.ylim(-0.5, 2)
plt.xlim(0,8)
plt.show()

# %% [markdown]
# ### Random Signal

# %%
import random
import numpy as np
import matplotlib.pyplot as plt


t = np.linspace(-0.02, 0.05, 50)
randomlist = random.sample(range(1, 60), 50)
plt.plot(t, randomlist);
plt.xlabel('t');
plt.ylabel('x(t)');
plt.title(r'Plot of Random Signal');
plt.xlim([-0.02, 0.05]);
plt.show()
