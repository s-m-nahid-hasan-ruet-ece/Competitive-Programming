# %% [markdown]
# ### **Analysis of Discrete Time Systems**
# #### ***Task:***  *Representation of discrete time systems*
#
# **Output:**
# - Linear, Non-Linear
# - Causal, Non-causal
# - Stable, Unstable
# - Impulse

# %% [markdown]
# ### **Linear & Non-Linear System**
#
# **Definition of Linear System:** A system is said to be linear if it follows both the Homogenity and Additivity principles.
#
# **Definition of Non-linear System:** A system is said to be non-linear if it does not follows the Homogenity and Additivity principles.
#
# **Homogenity:** If the input is multiplied by a constant, the output shall also be multiplied by the same.
#
# **Additivity:** If an input x1(t) produces output y1(t) and another input x2(t) also acting along produces output y2(t), then when both inputs acting on the system simultaneously produces output y1(t)+y2(t).
#
# #### **Conditions**
# - The output should not be zero when input applied is zero.
# - Any non-linear operator can be applied on the either input or on the output to make the system non-linear.
#
#
# #### **Example of Linear Systems:**
# - y(n) = n*x(n)
# - y(n) = x(n*n)
# - y(n) = A*x(n) + B ; B=0
#
# #### **Example of Non-linear Systems:**
# - y(n) = x*x(n)
# - y(n) = A*x(n) + B ; B!=0
# - y(n) = e^x(n)

# %% [markdown]
# # **Linear System**

# %%
#  Linear Systems


import numpy as np
import matplotlib.pyplot as plt
import copy as cpy

n = np.linspace(0,200,30)
#expression = input("Enter the function(in terms of x):")

x = lambda a: 3*a+2
y = [ 5*x(n) for n in n]


plt.figure(figsize=(25, 8))
plt.stem(n,y)
# Out:
# <StemContainer object of 3 artists>

# %% [markdown]
# # **Non-linear System**

# %%
#  Non-linear System

x = lambda a: 3*a
y = [ pow(2,x(n)) for n in n]
#pow(np.e,x(n))

plt.figure(figsize=(25, 8))
plt.stem(n,y)
# Out:
# <StemContainer object of 3 artists>

# %% [markdown]
# # **Causal & Non-causal System**
#
# **Definition of Causal System:** A system whose output or response at any time instant (t) depends only on the present and past values of the input but not on the future values of the input is called the causal system.
#
# **Definition of Non-causal System:** A system whose output or response at any time instant (t) depends upon future values of the input is called the non-causal system.
#
#
#
# #### **Example of Causal Systems:**
# - y(n) = x(n) - x(n-1)
# - y(n) = x(k1)+x(k2)+....+x(kn) ; where ki = [-inf,n]
# - y(n) = ax(n)
#
# #### **Example of Non-causal Systems:**
# - y(n) = x(n) + 3x(n+4)
# - y(n) = x(n*n)
# - y(n) = x(2*n)
# - y(n) = x(-n)

# %% [markdown]
# # **Causal System**

# %%
#  Causal System
#  y(n) = x(n) - x(n-1)

n = np.linspace(1,29,30)
nn = np.linspace(1,29,28)

xx = lambda a: 3*a+5
x = [ xx(n) for n in n]

y = []

for i in range(1,len(x)-1):
    y.append(x[i]+x[i-1])

plt.figure(figsize=(25, 8))
plt.stem(nn,y)
# Out:
# <StemContainer object of 3 artists>

# %%
print("                   VALIDATION         ")

for i in range(1, len(y)):
    print("x[%d]= %lf + x[%d]=%lf  = y[%d]= %lf  " % (i,x[i],i-1,x[i-1],i,y[i-1]))
# Out:
#                    VALIDATION
# x[1]= 10.896552 + x[0]=8.000000  = y[1]= 18.896552
# x[2]= 13.793103 + x[1]=10.896552  = y[2]= 24.689655
# x[3]= 16.689655 + x[2]=13.793103  = y[3]= 30.482759
# x[4]= 19.586207 + x[3]=16.689655  = y[4]= 36.275862
# x[5]= 22.482759 + x[4]=19.586207  = y[5]= 42.068966
# x[6]= 25.379310 + x[5]=22.482759  = y[6]= 47.862069
# x[7]= 28.275862 + x[6]=25.379310  = y[7]= 53.655172
# x[8]= 31.172414 + x[7]=28.275862  = y[8]= 59.448276
# x[9]= 34.068966 + x[8]=31.172414  = y[9]= 65.241379
# x[10]= 36.965517 + x[9]=34.068966  = y[10]= 71.034483
# x[11]= 39.862069 + x[10]=36.965517  = y[11]= 76.827586
# x[12]= 42.758621 + x[11]=39.862069  = y[12]= 82.620690
# x[13]= 45.655172 + x[12]=42.758621  = y[13]= 88.413793
# x[14]= 48.551724 + x[13]=45.655172  = y[14]= 94.206897
# x[15]= 51.448276 + x[14]=48.551724  = y[15]= 100.000000
# x[16]= 54.344828 + x[15]=51.448276  = y[16]= 105.793103
# x[17]= 57.241379 + x[16]=54.344828  = y[17]= 111.586207
# x[18]= 60.137931 + x[17]=57.241379  = y[18]= 117.379310
# x[19]= 63.034483 + x[18]=60.137931  = y[19]= 123.172414
# x[20]= 65.931034 + x[19]=63.034483  = y[20]= 128.965517
# x[21]= 68.827586 + x[20]=65.931034  = y[21]= 134.758621
# x[22]= 71.724138 + x[21]=68.827586  = y[22]= 140.551724
# x[23]= 74.620690 + x[22]=71.724138  = y[23]= 146.344828
# x[24]= 77.517241 + x[23]=74.620690  = y[24]= 152.137931
# x[25]= 80.413793 + x[24]=77.517241  = y[25]= 157.931034
# x[26]= 83.310345 + x[25]=80.413793  = y[26]= 163.724138
# x[27]= 86.206897 + x[26]=83.310345  = y[27]= 169.517241

# %% [markdown]
# # **Non-causal System**

# %%
#  Non-causal System
#  y(n) = x(n) + 3x(n+4)


n = np.linspace(0,29,30)
nn = np.linspace(0,25,26)

xfunc = lambda a: 3*a
x = [ xfunc(n) for n in n]

y = []

for i in range(0,len(x)-4):
    y.append(x[i] + 3*x[i+4])

plt.figure(figsize=(25, 8))
plt.stem(nn,y)
# Out:
# 26
# <StemContainer object of 3 artists>

# %%
print("                   VALIDATION         ")

for i in range(0, len(y)-4):
    print("x[%d]= %lf + 3*x[%d]=%lf  = y[%d]= %lf  " % (i,x[i],i+4,3*x[i+4],i,y[i]))
# Out:
#                    VALIDATION
# x[0]= 0.000000 + 3*x[4]=36.000000  = y[0]= 36.000000
# x[1]= 3.000000 + 3*x[5]=45.000000  = y[1]= 48.000000
# x[2]= 6.000000 + 3*x[6]=54.000000  = y[2]= 60.000000
# x[3]= 9.000000 + 3*x[7]=63.000000  = y[3]= 72.000000
# x[4]= 12.000000 + 3*x[8]=72.000000  = y[4]= 84.000000
# x[5]= 15.000000 + 3*x[9]=81.000000  = y[5]= 96.000000
# x[6]= 18.000000 + 3*x[10]=90.000000  = y[6]= 108.000000
# x[7]= 21.000000 + 3*x[11]=99.000000  = y[7]= 120.000000
# x[8]= 24.000000 + 3*x[12]=108.000000  = y[8]= 132.000000
# x[9]= 27.000000 + 3*x[13]=117.000000  = y[9]= 144.000000
# x[10]= 30.000000 + 3*x[14]=126.000000  = y[10]= 156.000000
# x[11]= 33.000000 + 3*x[15]=135.000000  = y[11]= 168.000000
# x[12]= 36.000000 + 3*x[16]=144.000000  = y[12]= 180.000000
# x[13]= 39.000000 + 3*x[17]=153.000000  = y[13]= 192.000000
# x[14]= 42.000000 + 3*x[18]=162.000000  = y[14]= 204.000000
# x[15]= 45.000000 + 3*x[19]=171.000000  = y[15]= 216.000000
# x[16]= 48.000000 + 3*x[20]=180.000000  = y[16]= 228.000000
# x[17]= 51.000000 + 3*x[21]=189.000000  = y[17]= 240.000000
# x[18]= 54.000000 + 3*x[22]=198.000000  = y[18]= 252.000000
# x[19]= 57.000000 + 3*x[23]=207.000000  = y[19]= 264.000000
# x[20]= 60.000000 + 3*x[24]=216.000000  = y[20]= 276.000000
# x[21]= 63.000000 + 3*x[25]=225.000000  = y[21]= 288.000000

# %% [markdown]
# ### **Stable & Unstable System**
#
# **Definition of Stable System:** An arbitrary relaxed system is said to be bounded input-bounded outpout(BIBO) stable if and only if every bounded input produces a bounded output.
#
# **Definition of Unstable System:** An arbitrary relaxed system is said to be unstable if and only if every bounded input produces an unbounded output.
#
#
#
# #### **Example of Stable Systems:**
# - y(n) = x(n) - x(n-1)
# - y(n) = 5x(n)
# - y(n) = x(n) + 3x(n+4)
# - y(n) = x(n*n)
# - y(n) = x(2*n)
# - y(n) = x(-n)
# #### **Example of Unstable Systems:**
# - y(n) = x(k1)+x(k2)+....+x(kn) ; where ki = [-inf,n]
# - y(n) = C*x(k1)+ C*x(k2)+....+Cx(kn) ; where ki = [-inf,n]

# %% [markdown]
# # **Stable System**

# %%
#  Stable System
#  y(n) = x(2*n)

n = np.linspace(1,29,30)
nn = np.linspace(1,29,28)

xx = lambda a: a*a+3*a+50
x = [ xx(n) for n in n]

y = []

for i in range(1,len(x)-1):
    y.append(x[i]+x[i-1])

plt.figure(figsize=(25, 8))
plt.stem(nn,y)
# Out:
# <StemContainer object of 3 artists>

# %% [markdown]
# # **Unstable System**

# %%
#  Unstable System
#  y(n) = C*x(k1)+ C*x(k2)+....+C*x(kn) ; where ki = [0,n], C = 10

n = np.linspace(1,29,30)
C = 10

xx = lambda a: 3*a+5
x = [ xx(n) for n in n]

y = []

for i in range(0,len(x)):
    sum =0
    for j in range(0,i):
       sum+= C*x[j]
    y.append(sum)

plt.figure(figsize=(25, 8))
plt.stem(n,y)
# Out:
# <StemContainer object of 3 artists>

# %% [markdown]
# ### **Impulse Signal**
#
# **Definition of Impulse Signal:** An ideal impulse signal is a signal that is zero everywhere but at the origin (t = 0), it is infinitely high. Although, the area of the impulse is finite. The unit impulse signal is the most widely used standard signal used in the analysis of signals and systems.
#
#
#
#
# #### **Example of Impulse Signal:**
# - δ(t)= { 1  when t=0 & 0 when t!=0

# %%
n = np.linspace(-10,10,21)

y = []

for i in range(0,len(n)):
    if(n[i]==0):
       y.append(1)
    else:
       y.append(0)


plt.figure(figsize=(25, 8))
plt.stem(n,y)
# Out:
# <StemContainer object of 3 artists>
